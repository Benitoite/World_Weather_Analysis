# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID              City      Lat       Lng          Weather  Max Temp  \
# 0        0       San Jose,Bo -17.9389  -63.3516  overcast clouds     75.00
# 1        1      El Carmen,Co   8.5106  -73.4478  overcast clouds     65.14
# 2        2      Sarangani,Ph   5.4033  125.4636    broken clouds     82.35
# 3        3   Punta Arenas,Cl -53.1500  -70.9167        clear sky     35.71
# 4        4  Mar Del Plata,Ar -38.0023  -57.5575  overcast clouds     55.42
#
#    Humidity  Cloudiness  Wind Speed Country                 Date
# 0        50          97       10.85      BO  2021-09-20 07:49:31
# 1        97         100        3.58      CO  2021-09-20 07:49:33
# 2        70          81        3.38      PH  2021-09-20 07:49:34
# 3        87           0        6.91      CL  2021-09-20 07:49:35
# 4       100          90        4.61      AR  2021-09-20 07:49:10

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 40
# What is the maximum temperature you would like for your trip? 68

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID              City      Lat       Lng           Weather  Max Temp  \
# 1         1      El Carmen,Co   8.5106  -73.4478   overcast clouds     65.14
# 4         4  Mar Del Plata,Ar -38.0023  -57.5575   overcast clouds     55.42
# 6         6     Nikolskoye,Ru  59.7035   30.7861   overcast clouds     43.02
# 8         8         Albany,Au -35.0169  117.8917   overcast clouds     61.23
# 9         9           Lebu,Cl -37.6167  -73.6500         clear sky     45.09
# 15       15       Zhigansk,Ru  66.7697  123.3711  scattered clouds     40.37
# 16       16       Hermanus,Za -34.4187   19.2345        light rain     53.91
# 17       17    East London,Za -33.0153   27.9116     broken clouds     61.74
# 18       18      Cape Town,Za -33.9258   18.4232     broken clouds     56.88
# 19       19         Lompoc,Us  34.6391 -120.4579              mist     65.79
#
#     Humidity  Cloudiness  Wind Speed Country                 Date
# ...

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df[ (preferred_cities_df["Lat"].isnull()) & (preferred_cities_df["City"]==u'') ].index
# Out:
# Int64Index([], dtype='int64')

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = preferred_cities_df.drop(   (preferred_cities_df[ (preferred_cities_df['Lat'].isnull()) & (preferred_cities_df['City']==u'')].index), axis=0, inplace=False)

# %%
clean_df
# Out:
#      City_ID              City      Lat       Lng           Weather  Max Temp  \
# 1          1      El Carmen,Co   8.5106  -73.4478   overcast clouds     65.14
# 4          4  Mar Del Plata,Ar -38.0023  -57.5575   overcast clouds     55.42
# 6          6     Nikolskoye,Ru  59.7035   30.7861   overcast clouds     43.02
# 8          8         Albany,Au -35.0169  117.8917   overcast clouds     61.23
# 9          9           Lebu,Cl -37.6167  -73.6500         clear sky     45.09
# ..       ...               ...      ...       ...               ...       ...
# 630      630       Kamloops,Ca  50.6665 -120.3192     broken clouds     49.19
# 637      637         Suntar,Ru  62.1444  117.6319  scattered clouds     49.06
# 638      638    Storforshei,No  66.4043   14.5233     broken clouds     47.98
# 642      642        Taksimo,Ru  56.3444  114.8794         clear sky     60.24
# 644      644   Port Augusta,Au -32.5000  137.7667  scattered clouds     56.71
#
# ...

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Weather", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                 City Country  Max Temp           Weather      Lat       Lng  \
# 1       El Carmen,Co      CO     65.14   overcast clouds   8.5106  -73.4478
# 4   Mar Del Plata,Ar      AR     55.42   overcast clouds -38.0023  -57.5575
# 6      Nikolskoye,Ru      RU     43.02   overcast clouds  59.7035   30.7861
# 8          Albany,Au      AU     61.23   overcast clouds -35.0169  117.8917
# 9            Lebu,Cl      CL     45.09         clear sky -37.6167  -73.6500
# 15       Zhigansk,Ru      RU     40.37  scattered clouds  66.7697  123.3711
# 16       Hermanus,Za      ZA     53.91        light rain -34.4187   19.2345
# 17    East London,Za      ZA     61.74     broken clouds -33.0153   27.9116
# 18      Cape Town,Za      ZA     56.88     broken clouds -33.9258   18.4232
# 19         Lompoc,Us      US     65.79              mist  34.6391 -120.4579
#
#    Hotel Name
# 1
# 4
# 6
# 8
# 9
# 15
# 16
# 17
# 18
# 19

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    # 6c. Get latitude and longitude from DataFrame
    lat = row[["Lat"]]
    long = row[["Lng"]]

    # 6d. Set up the base URL for the Google **PLACES** API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat[0]},{long[0]}"

    # Grab the first hotel from the results and store the name.
    try:
        hotelname = ''
        hotels = requests.get(base_url, params=params).json()
        hotelname = (hotels['results'][0]['name'])
        hotel_df.loc[index, "Hotel Name"] = hotelname
        print(row[['City']], hotelname, index)
        hotels.clear()
    except (IndexError):
        print("Hotel not found... skipping.")
        hotels.clear()
        pass
# Out:
# City    El Carmen,Co
# Name: 1, dtype: object Hotel La Casona 1
# City    Mar Del Plata,Ar
# Name: 4, dtype: object Gran Hotel Mar del Plata 4
# City    Nikolskoye,Ru
# Name: 6, dtype: object Tourist House - Sablino 6
# City    Albany,Au
# Name: 8, dtype: object Dog Rock Motel 8
# City    Lebu,Cl
# Name: 9, dtype: object Hostal Las Lilas 9
# City    Zhigansk,Ru
# Name: 15, dtype: object Gostinichnyy Kompleks Aylgy 15
# City    Hermanus,Za
# Name: 16, dtype: object Misty Waves Boutique Hotel 16
# City    East London,Za
# Name: 17, dtype: object Tu Casa 17
# City    Cape Town,Za
# Name: 18, dtype: object Southern Sun Waterfront Cape Town 18
# City    Lompoc,Us
# Name: 19, dtype: object Holiday Inn Express Lompoc, an IHG Hotel 19
# City    Kodiak,Us
# Name: 22, dtype: object Best Western Kodiak Inn And Convention Center 22
# City    Jamestown,Sh
# Name: 23, dtype: object Consulate 23
# City    Roald,No
# Name: 24, dtype: object Flem Cabins 24
# City    Rusne,Lt
# ...

# %%
hotel_df.head(60)
# Out:
#                       City Country  Max Temp           Weather      Lat  \
# 1             El Carmen,Co      CO     65.14   overcast clouds   8.5106
# 4         Mar Del Plata,Ar      AR     55.42   overcast clouds -38.0023
# 6            Nikolskoye,Ru      RU     43.02   overcast clouds  59.7035
# 8                Albany,Au      AU     61.23   overcast clouds -35.0169
# 9                  Lebu,Cl      CL     45.09         clear sky -37.6167
# 15             Zhigansk,Ru      RU     40.37  scattered clouds  66.7697
# 16             Hermanus,Za      ZA     53.91        light rain -34.4187
# 17          East London,Za      ZA     61.74     broken clouds -33.0153
# 18            Cape Town,Za      ZA     56.88     broken clouds -33.9258
# 19               Lompoc,Us      US     65.79              mist  34.6391
# 22               Kodiak,Us      US     47.43        light rain  57.7900
# 23            Jamestown,Sh      SH     62.22   overcast clouds -15.9387
# ...

# %%
# 7. Drop the rows where there is no Hotel Name.

clean_hotel_df = hotel_df.drop((hotel_df[(hotel_df['Hotel Name']=='')].index), axis=0, inplace=False)

# %%
# 8a. Create the output File (CSV)
output_data_file = "Vacation_Search/WeatherPy_vacation.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather</dt><dd>{Weather}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
max_temp = clean_hotel_df["Max Temp"]
# 11a. Add a marker layer for each city to the map. 
#marker_layer = gmaps.marker_layer(locations)

marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# 11b. Display the figure
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
