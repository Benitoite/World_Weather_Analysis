# %%
# Import the datetime module from the datetime library.
from datetime import datetime
import pandas as pd
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time

# Initialize dataframes and get city data

# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    a = [citipy.nearest_city(coordinate[0], coordinate[1]).city_name, ",", citipy.nearest_city(coordinate[0], coordinate[1]).country_code]
    city = "".join(a)
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
        # Create an empty list to hold the weather data.
city_data = []

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    print(city)
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_wx = city_weather['weather'][0]['description']
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Weather": city_wx,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    # Add 1 to the record count.
    record_count += 1
    time.sleep(1)


# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# san jose,bo
# Processing Record 1 of Set 1 | san jose,bo
# el carmen,co
# Processing Record 2 of Set 1 | el carmen,co
# sarangani,ph
# Processing Record 3 of Set 1 | sarangani,ph
# punta arenas,cl
# Processing Record 4 of Set 1 | punta arenas,cl
# mar del plata,ar
# Processing Record 5 of Set 1 | mar del plata,ar
# rikitea,pf
# Processing Record 6 of Set 1 | rikitea,pf
# nikolskoye,ru
# Processing Record 7 of Set 1 | nikolskoye,ru
# tikrit,iq
# Processing Record 8 of Set 1 | tikrit,iq
# albany,au
# Processing Record 9 of Set 1 | albany,au
# lebu,cl
# Processing Record 10 of Set 1 | lebu,cl
# kapaa,us
# Processing Record 11 of Set 1 | kapaa,us
# bengkulu,id
# Processing Record 12 of Set 1 | bengkulu,id
# kommunisticheskiy,ru
# Processing Record 13 of Set 1 | kommunisticheskiy,ru
# hithadhoo,mv
# Processing Record 14 of Set 1 | hithadhoo,mv
# arraial do cabo,br
# Processing Record 15 of Set 1 | arraial do cabo,br
# zhigansk,ru
# Processing Record 16 of Set 1 | zhigansk,ru
# hermanus,za
# Processing Record 17 of Set 1 | hermanus,za
# east london,za
# Processing Record 18 of Set 1 | east london,za
# cape town,za
# Processing Record 19 of Set 1 | cape town,za
# barentsburg,sj
# Processing Record 20 of Set 1 | barentsburg,sj
# City not found. Skipping...
# lompoc,us
# Processing Record 21 of Set 1 | lompoc,us
# geraldton,au
# Processing Record 22 of Set 1 | geraldton,au
# qui nhon,vn
# Processing Record 23 of Set 1 | qui nhon,vn
# kodiak,us
# Processing Record 24 of Set 1 | kodiak,us
# jamestown,sh
# Processing Record 25 of Set 1 | jamestown,sh
# roald,no
# Processing Record 26 of Set 1 | roald,no
# nome,us
# Processing Record 27 of Set 1 | nome,us
# samarkand,uz
# Processing Record 28 of Set 1 | samarkand,uz
# guangyuan,cn
# Processing Record 29 of Set 1 | guangyuan,cn
# tauramena,co
# Processing Record 30 of Set 1 | tauramena,co
# rusne,lt
# Processing Record 31 of Set 1 | rusne,lt
# parati,br
# Processing Record 32 of Set 1 | parati,br
# saldanha,za
# Processing Record 33 of Set 1 | saldanha,za
# fevralsk,ru
# Processing Record 34 of Set 1 | fevralsk,ru
# City not found. Skipping...
# hilsa,in
# Processing Record 35 of Set 1 | hilsa,in
# leonforte,it
# Processing Record 36 of Set 1 | leonforte,it
# bethel,us
# Processing Record 37 of Set 1 | bethel,us
# ancud,cl
# Processing Record 38 of Set 1 | ancud,cl
# illoqqortoormiut,gl
# Processing Record 39 of Set 1 | illoqqortoormiut,gl
# City not found. Skipping...
# hasaki,jp
# Processing Record 40 of Set 1 | hasaki,jp
# busselton,au
# Processing Record 41 of Set 1 | busselton,au
# faanui,pf
# Processing Record 42 of Set 1 | faanui,pf
# puerto ayora,ec
# Processing Record 43 of Set 1 | puerto ayora,ec
# torbay,ca
# Processing Record 44 of Set 1 | torbay,ca
# severnyy,ru
# Processing Record 45 of Set 1 | severnyy,ru
# belushya guba,ru
# Processing Record 46 of Set 1 | belushya guba,ru
# City not found. Skipping...
# raudeberg,no
# Processing Record 47 of Set 1 | raudeberg,no
# luderitz,na
# Processing Record 48 of Set 1 | luderitz,na
# ahipara,nz
# Processing Record 49 of Set 1 | ahipara,nz
# castro,cl
# Processing Record 50 of Set 1 | castro,cl
# verkhniye tatyshly,ru
# Processing Record 1 of Set 2 | verkhniye tatyshly,ru
# cam ranh,vn
# Processing Record 2 of Set 2 | cam ranh,vn
# souillac,mu
# Processing Record 3 of Set 2 | souillac,mu
# nanortalik,gl
# Processing Record 4 of Set 2 | nanortalik,gl
# haverfordwest,gb
# Processing Record 5 of Set 2 | haverfordwest,gb
# vavuniya,lk
# Processing Record 6 of Set 2 | vavuniya,lk
# new norfolk,au
# Processing Record 7 of Set 2 | new norfolk,au
# gamba,ga
# Processing Record 8 of Set 2 | gamba,ga
# bluff,nz
# Processing Record 9 of Set 2 | bluff,nz
# meyungs,pw
# Processing Record 10 of Set 2 | meyungs,pw
# City not found. Skipping...
# airai,pw
# Processing Record 11 of Set 2 | airai,pw
# City not found. Skipping...
# honiara,sb
# Processing Record 12 of Set 2 | honiara,sb
# dikson,ru
# Processing Record 13 of Set 2 | dikson,ru
# uwayl,sd
# Processing Record 14 of Set 2 | uwayl,sd
# City not found. Skipping...
# asau,tv
# Processing Record 15 of Set 2 | asau,tv
# City not found. Skipping...
# acajutla,sv
# Processing Record 16 of Set 2 | acajutla,sv
# svetlogorsk,ru
# Processing Record 17 of Set 2 | svetlogorsk,ru
# hilo,us
# Processing Record 18 of Set 2 | hilo,us
# katobu,id
# Processing Record 19 of Set 2 | katobu,id
# qafsah,tn
# Processing Record 20 of Set 2 | qafsah,tn
# City not found. Skipping...
# mataura,pf
# Processing Record 21 of Set 2 | mataura,pf
# City not found. Skipping...
# taolanaro,mg
# Processing Record 22 of Set 2 | taolanaro,mg
# City not found. Skipping...
# lakatoro,vu
# Processing Record 23 of Set 2 | lakatoro,vu
# ixtapa,mx
# Processing Record 24 of Set 2 | ixtapa,mx
# tuktoyaktuk,ca
# Processing Record 25 of Set 2 | tuktoyaktuk,ca
# bordighera,it
# Processing Record 26 of Set 2 | bordighera,it
# caravelas,br
# Processing Record 27 of Set 2 | caravelas,br
# saskylakh,ru
# Processing Record 28 of Set 2 | saskylakh,ru
# hobart,au
# Processing Record 29 of Set 2 | hobart,au
# sumbawa,id
# Processing Record 30 of Set 2 | sumbawa,id
# City not found. Skipping...
# otake,jp
# Processing Record 31 of Set 2 | otake,jp
# butaritari,ki
# Processing Record 32 of Set 2 | butaritari,ki
# san policarpo,ph
# Processing Record 33 of Set 2 | san policarpo,ph
# norman wells,ca
# Processing Record 34 of Set 2 | norman wells,ca
# naryan-mar,ru
# Processing Record 35 of Set 2 | naryan-mar,ru
# vila franca do campo,pt
# Processing Record 36 of Set 2 | vila franca do campo,pt
# ereymentau,kz
# Processing Record 37 of Set 2 | ereymentau,kz
# iqaluit,ca
# Processing Record 38 of Set 2 | iqaluit,ca
# port alfred,za
# Processing Record 39 of Set 2 | port alfred,za
# lavrentiya,ru
# Processing Record 40 of Set 2 | lavrentiya,ru
# port blair,in
# Processing Record 41 of Set 2 | port blair,in
# aguimes,es
# Processing Record 42 of Set 2 | aguimes,es
# dingle,ie
# Processing Record 43 of Set 2 | dingle,ie
# buraydah,sa
# Processing Record 44 of Set 2 | buraydah,sa
# rio gallegos,ar
# Processing Record 45 of Set 2 | rio gallegos,ar
# kungurtug,ru
# Processing Record 46 of Set 2 | kungurtug,ru
# mys shmidta,ru
# Processing Record 47 of Set 2 | mys shmidta,ru
# City not found. Skipping...
# brae,gb
# Processing Record 48 of Set 2 | brae,gb
# attawapiskat,ca
# Processing Record 49 of Set 2 | attawapiskat,ca
# City not found. Skipping...
# tiksi,ru
# Processing Record 50 of Set 2 | tiksi,ru
# terrace bay,ca
# Processing Record 1 of Set 3 | terrace bay,ca
# tautira,pf
# Processing Record 2 of Set 3 | tautira,pf
# dukat,ru
# Processing Record 3 of Set 3 | dukat,ru
# palmer,us
# Processing Record 4 of Set 3 | palmer,us
# ilulissat,gl
# Processing Record 5 of Set 3 | ilulissat,gl
# shingu,jp
# Processing Record 6 of Set 3 | shingu,jp
# roebourne,au
# Processing Record 7 of Set 3 | roebourne,au
# victoria,sc
# Processing Record 8 of Set 3 | victoria,sc
# grand river south east,mu
# Processing Record 9 of Set 3 | grand river south east,mu
# City not found. Skipping...
# ust-nera,ru
# Processing Record 10 of Set 3 | ust-nera,ru
# mareeba,au
# Processing Record 11 of Set 3 | mareeba,au
# nizhneyansk,ru
# Processing Record 12 of Set 3 | nizhneyansk,ru
# City not found. Skipping...
# alofi,nu
# Processing Record 13 of Set 3 | alofi,nu
# vaini,to
# Processing Record 14 of Set 3 | vaini,to
# senneterre,ca
# Processing Record 15 of Set 3 | senneterre,ca
# bekovo,ru
# Processing Record 16 of Set 3 | bekovo,ru
# qaanaaq,gl
# Processing Record 17 of Set 3 | qaanaaq,gl
# atuona,pf
# Processing Record 18 of Set 3 | atuona,pf
# ponta do sol,cv
# Processing Record 19 of Set 3 | ponta do sol,cv
# concepcion,py
# Processing Record 20 of Set 3 | concepcion,py
# afanasyevo,ru
# Processing Record 21 of Set 3 | afanasyevo,ru
# City not found. Skipping...
# boende,cd
# Processing Record 22 of Set 3 | boende,cd
# muisne,ec
# Processing Record 23 of Set 3 | muisne,ec
# louisbourg,ca
# Processing Record 24 of Set 3 | louisbourg,ca
# City not found. Skipping...
# lagoa,pt
# Processing Record 25 of Set 3 | lagoa,pt
# kaitangata,nz
# Processing Record 26 of Set 3 | kaitangata,nz
# altonia,br
# Processing Record 27 of Set 3 | altonia,br
# City not found. Skipping...
# riyadh,sa
# Processing Record 28 of Set 3 | riyadh,sa
# reyes,bo
# Processing Record 29 of Set 3 | reyes,bo
# college,us
# Processing Record 30 of Set 3 | college,us
# avarua,ck
# Processing Record 31 of Set 3 | avarua,ck
# saint-augustin,ca
# Processing Record 32 of Set 3 | saint-augustin,ca
# severnoye,ru
# Processing Record 33 of Set 3 | severnoye,ru
# umm durman,sd
# Processing Record 34 of Set 3 | umm durman,sd
# City not found. Skipping...
# kandalaksha,ru
# Processing Record 35 of Set 3 | kandalaksha,ru
# yantal,ru
# Processing Record 36 of Set 3 | yantal,ru
# isangel,vu
# Processing Record 37 of Set 3 | isangel,vu
# ribeira grande,pt
# Processing Record 38 of Set 3 | ribeira grande,pt
# horqueta,py
# Processing Record 39 of Set 3 | horqueta,py
# baijiantan,cn
# Processing Record 40 of Set 3 | baijiantan,cn
# imperia,it
# Processing Record 41 of Set 3 | imperia,it
# pacific grove,us
# Processing Record 42 of Set 3 | pacific grove,us
# laguna de duero,es
# Processing Record 43 of Set 3 | laguna de duero,es
# bredasdorp,za
# Processing Record 44 of Set 3 | bredasdorp,za
# guerrero negro,mx
# Processing Record 45 of Set 3 | guerrero negro,mx
# marsa matruh,eg
# Processing Record 46 of Set 3 | marsa matruh,eg
# port elizabeth,za
# Processing Record 47 of Set 3 | port elizabeth,za
# qaqortoq,gl
# Processing Record 48 of Set 3 | qaqortoq,gl
# sfantu gheorghe,ro
# Processing Record 49 of Set 3 | sfantu gheorghe,ro
# oranjestad,aw
# Processing Record 50 of Set 3 | oranjestad,aw
# ushuaia,ar
# Processing Record 1 of Set 4 | ushuaia,ar
# georgetown,sh
# Processing Record 2 of Set 4 | georgetown,sh
# paracale,ph
# Processing Record 3 of Set 4 | paracale,ph
# kolyshley,ru
# Processing Record 4 of Set 4 | kolyshley,ru
# talnakh,ru
# Processing Record 5 of Set 4 | talnakh,ru
# birao,cf
# Processing Record 6 of Set 4 | birao,cf
# khonuu,ru
# Processing Record 7 of Set 4 | khonuu,ru
# City not found. Skipping...
# mount pleasant,us
# Processing Record 8 of Set 4 | mount pleasant,us
# mitsamiouli,km
# Processing Record 9 of Set 4 | mitsamiouli,km
# nabire,id
# Processing Record 10 of Set 4 | nabire,id
# elko,us
# Processing Record 11 of Set 4 | elko,us
# necochea,ar
# Processing Record 12 of Set 4 | necochea,ar
# manzil tamim,tn
# Processing Record 13 of Set 4 | manzil tamim,tn
# City not found. Skipping...
# longyearbyen,sj
# Processing Record 14 of Set 4 | longyearbyen,sj
# sistranda,no
# Processing Record 15 of Set 4 | sistranda,no
# severomuysk,ru
# Processing Record 16 of Set 4 | severomuysk,ru
# atbasar,kz
# Processing Record 17 of Set 4 | atbasar,kz
# upernavik,gl
# Processing Record 18 of Set 4 | upernavik,gl
# severo-kurilsk,ru
# Processing Record 19 of Set 4 | severo-kurilsk,ru
# kazachinskoye,ru
# Processing Record 20 of Set 4 | kazachinskoye,ru
# corinto,ni
# Processing Record 21 of Set 4 | corinto,ni
# rio grande,br
# Processing Record 22 of Set 4 | rio grande,br
# soe,id
# Processing Record 23 of Set 4 | soe,id
# barrow,us
# Processing Record 24 of Set 4 | barrow,us
# gubkinskiy,ru
# Processing Record 25 of Set 4 | gubkinskiy,ru
# samusu,ws
# Processing Record 26 of Set 4 | samusu,ws
# City not found. Skipping...
# carnarvon,au
# Processing Record 27 of Set 4 | carnarvon,au
# richards bay,za
# Processing Record 28 of Set 4 | richards bay,za
# taitung,tw
# Processing Record 29 of Set 4 | taitung,tw
# kieta,pg
# Processing Record 30 of Set 4 | kieta,pg
# west wendover,us
# Processing Record 31 of Set 4 | west wendover,us
# chokurdakh,ru
# Processing Record 32 of Set 4 | chokurdakh,ru
# mrirt,ma
# Processing Record 33 of Set 4 | mrirt,ma
# City not found. Skipping...
# berovo,mk
# Processing Record 34 of Set 4 | berovo,mk
# astoria,us
# Processing Record 35 of Set 4 | astoria,us
# biloela,au
# Processing Record 36 of Set 4 | biloela,au
# axim,gh
# Processing Record 37 of Set 4 | axim,gh
# honningsvag,no
# Processing Record 38 of Set 4 | honningsvag,no
# tasiilaq,gl
# Processing Record 39 of Set 4 | tasiilaq,gl
# sitka,us
# Processing Record 40 of Set 4 | sitka,us
# chuy,uy
# Processing Record 41 of Set 4 | chuy,uy
# kuche,cn
# Processing Record 42 of Set 4 | kuche,cn
# City not found. Skipping...
# sisimiut,gl
# Processing Record 43 of Set 4 | sisimiut,gl
# biak,id
# Processing Record 44 of Set 4 | biak,id
# salon,in
# Processing Record 45 of Set 4 | salon,in
# igarka,ru
# Processing Record 46 of Set 4 | igarka,ru
# lorengau,pg
# Processing Record 47 of Set 4 | lorengau,pg
# marquette,us
# Processing Record 48 of Set 4 | marquette,us
# narrabri,au
# Processing Record 49 of Set 4 | narrabri,au
# voh,nc
# Processing Record 50 of Set 4 | voh,nc
# peniche,pt
# Processing Record 1 of Set 5 | peniche,pt
# silver city,us
# Processing Record 2 of Set 5 | silver city,us
# acara,br
# Processing Record 3 of Set 5 | acara,br
# manta,ec
# Processing Record 4 of Set 5 | manta,ec
# saleaula,ws
# Processing Record 5 of Set 5 | saleaula,ws
# City not found. Skipping...
# tomatlan,mx
# Processing Record 6 of Set 5 | tomatlan,mx
# cabo san lucas,mx
# Processing Record 7 of Set 5 | cabo san lucas,mx
# thinadhoo,mv
# Processing Record 8 of Set 5 | thinadhoo,mv
# ruatoria,nz
# Processing Record 9 of Set 5 | ruatoria,nz
# City not found. Skipping...
# jiroft,ir
# Processing Record 10 of Set 5 | jiroft,ir
# City not found. Skipping...
# vestmannaeyjar,is
# Processing Record 11 of Set 5 | vestmannaeyjar,is
# waingapu,id
# Processing Record 12 of Set 5 | waingapu,id
# sao joao da barra,br
# Processing Record 13 of Set 5 | sao joao da barra,br
# southbridge,nz
# Processing Record 14 of Set 5 | southbridge,nz
# mahebourg,mu
# Processing Record 15 of Set 5 | mahebourg,mu
# road town,vg
# Processing Record 16 of Set 5 | road town,vg
# fairbanks,us
# Processing Record 17 of Set 5 | fairbanks,us
# shirokiy,ru
# Processing Record 18 of Set 5 | shirokiy,ru
# krasnoselkup,ru
# Processing Record 19 of Set 5 | krasnoselkup,ru
# olga,ru
# Processing Record 20 of Set 5 | olga,ru
# coquimbo,cl
# Processing Record 21 of Set 5 | coquimbo,cl
# baikunthpur,in
# Processing Record 22 of Set 5 | baikunthpur,in
# doha,kw
# Processing Record 23 of Set 5 | doha,kw
# City not found. Skipping...
# camacha,pt
# Processing Record 24 of Set 5 | camacha,pt
# muros,es
# Processing Record 25 of Set 5 | muros,es
# kamaishi,jp
# Processing Record 26 of Set 5 | kamaishi,jp
# piacabucu,br
# Processing Record 27 of Set 5 | piacabucu,br
# kiunga,pg
# Processing Record 28 of Set 5 | kiunga,pg
# adrar,dz
# Processing Record 29 of Set 5 | adrar,dz
# havre-saint-pierre,ca
# Processing Record 30 of Set 5 | havre-saint-pierre,ca
# khatanga,ru
# Processing Record 31 of Set 5 | khatanga,ru
# yelizovo,ru
# Processing Record 32 of Set 5 | yelizovo,ru
# meulaboh,id
# Processing Record 33 of Set 5 | meulaboh,id
# gornyak,ru
# Processing Record 34 of Set 5 | gornyak,ru
# ternate,id
# Processing Record 35 of Set 5 | ternate,id
# dunedin,nz
# Processing Record 36 of Set 5 | dunedin,nz
# cidreira,br
# Processing Record 37 of Set 5 | cidreira,br
# tevaitoa,pf
# Processing Record 38 of Set 5 | tevaitoa,pf
# la primavera,co
# Processing Record 39 of Set 5 | la primavera,co
# katsuura,jp
# Processing Record 40 of Set 5 | katsuura,jp
# pevek,ru
# Processing Record 41 of Set 5 | pevek,ru
# merauke,id
# Processing Record 42 of Set 5 | merauke,id
# hay river,ca
# Processing Record 43 of Set 5 | hay river,ca
# rocha,uy
# Processing Record 44 of Set 5 | rocha,uy
# imeni poliny osipenko,ru
# Processing Record 45 of Set 5 | imeni poliny osipenko,ru
# bitung,id
# Processing Record 46 of Set 5 | bitung,id
# sentyabrskiy,ru
# Processing Record 47 of Set 5 | sentyabrskiy,ru
# City not found. Skipping...
# saint-pierre,pm
# Processing Record 48 of Set 5 | saint-pierre,pm
# avera,pf
# Processing Record 49 of Set 5 | avera,pf
# City not found. Skipping...
# karratha,au
# Processing Record 50 of Set 5 | karratha,au
# ilorin,ng
# Processing Record 1 of Set 6 | ilorin,ng
# lata,sb
# Processing Record 2 of Set 6 | lata,sb
# City not found. Skipping...
# yellowknife,ca
# Processing Record 3 of Set 6 | yellowknife,ca
# dicabisagan,ph
# Processing Record 4 of Set 6 | dicabisagan,ph
# kirovsk,ru
# Processing Record 5 of Set 6 | kirovsk,ru
# matagami,ca
# Processing Record 6 of Set 6 | matagami,ca
# toccoa,us
# Processing Record 7 of Set 6 | toccoa,us
# tambul,sd
# Processing Record 8 of Set 6 | tambul,sd
# City not found. Skipping...
# tsihombe,mg
# Processing Record 9 of Set 6 | tsihombe,mg
# City not found. Skipping...
# hibbing,us
# Processing Record 10 of Set 6 | hibbing,us
# zabol,ir
# Processing Record 11 of Set 6 | zabol,ir
# khorixas,na
# Processing Record 12 of Set 6 | khorixas,na
# livani,lv
# Processing Record 13 of Set 6 | livani,lv
# faya,td
# Processing Record 14 of Set 6 | faya,td
# City not found. Skipping...
# chagda,ru
# Processing Record 15 of Set 6 | chagda,ru
# City not found. Skipping...
# myitkyina,mm
# Processing Record 16 of Set 6 | myitkyina,mm
# satitoa,ws
# Processing Record 17 of Set 6 | satitoa,ws
# City not found. Skipping...
# saint-joseph,re
# Processing Record 18 of Set 6 | saint-joseph,re
# sao gabriel da cachoeira,br
# Processing Record 19 of Set 6 | sao gabriel da cachoeira,br
# ucluelet,ca
# Processing Record 20 of Set 6 | ucluelet,ca
# alyangula,au
# Processing Record 21 of Set 6 | alyangula,au
# jiangyou,cn
# Processing Record 22 of Set 6 | jiangyou,cn
# quatre cocos,mu
# Processing Record 23 of Set 6 | quatre cocos,mu
# tuatapere,nz
# Processing Record 24 of Set 6 | tuatapere,nz
# filadelfia,py
# Processing Record 25 of Set 6 | filadelfia,py
# takoradi,gh
# Processing Record 26 of Set 6 | takoradi,gh
# kobelyaky,ua
# Processing Record 27 of Set 6 | kobelyaky,ua
# ust-ilimsk,ru
# Processing Record 28 of Set 6 | ust-ilimsk,ru
# nuevo progreso,mx
# Processing Record 29 of Set 6 | nuevo progreso,mx
# turukhansk,ru
# Processing Record 30 of Set 6 | turukhansk,ru
# shakawe,bw
# Processing Record 31 of Set 6 | shakawe,bw
# agadez,ne
# Processing Record 32 of Set 6 | agadez,ne
# aykhal,ru
# Processing Record 33 of Set 6 | aykhal,ru
# san cristobal,ec
# Processing Record 34 of Set 6 | san cristobal,ec
# marawi,sd
# Processing Record 35 of Set 6 | marawi,sd
# bay roberts,ca
# Processing Record 36 of Set 6 | bay roberts,ca
# borogontsy,ru
# Processing Record 37 of Set 6 | borogontsy,ru
# huarmey,pe
# Processing Record 38 of Set 6 | huarmey,pe
# provideniya,ru
# Processing Record 39 of Set 6 | provideniya,ru
# sinnamary,gf
# Processing Record 40 of Set 6 | sinnamary,gf
# amazar,ru
# Processing Record 41 of Set 6 | amazar,ru
# hihifo,to
# Processing Record 42 of Set 6 | hihifo,to
# City not found. Skipping...
# salalah,om
# Processing Record 43 of Set 6 | salalah,om
# ambon,id
# Processing Record 44 of Set 6 | ambon,id
# cap malheureux,mu
# Processing Record 45 of Set 6 | cap malheureux,mu
# palana,ru
# Processing Record 46 of Set 6 | palana,ru
# wexford,ie
# Processing Record 47 of Set 6 | wexford,ie
# yeppoon,au
# Processing Record 48 of Set 6 | yeppoon,au
# xining,cn
# Processing Record 49 of Set 6 | xining,cn
# la sarre,ca
# Processing Record 50 of Set 6 | la sarre,ca
# bathsheba,bb
# Processing Record 1 of Set 7 | bathsheba,bb
# vao,nc
# Processing Record 2 of Set 7 | vao,nc
# hofn,is
# Processing Record 3 of Set 7 | hofn,is
# hami,cn
# Processing Record 4 of Set 7 | hami,cn
# pipri,in
# Processing Record 5 of Set 7 | pipri,in
# klaksvik,fo
# Processing Record 6 of Set 7 | klaksvik,fo
# poya,nc
# Processing Record 7 of Set 7 | poya,nc
# nelson bay,au
# Processing Record 8 of Set 7 | nelson bay,au
# magdagachi,ru
# Processing Record 9 of Set 7 | magdagachi,ru
# talcahuano,cl
# Processing Record 10 of Set 7 | talcahuano,cl
# asfi,ma
# Processing Record 11 of Set 7 | asfi,ma
# phan thiet,vn
# Processing Record 12 of Set 7 | phan thiet,vn
# acuna,mx
# Processing Record 13 of Set 7 | acuna,mx
# City not found. Skipping...
# kiama,au
# Processing Record 14 of Set 7 | kiama,au
# busing,ph
# Processing Record 15 of Set 7 | busing,ph
# henties bay,na
# Processing Record 16 of Set 7 | henties bay,na
# kapoeta,sd
# Processing Record 17 of Set 7 | kapoeta,sd
# City not found. Skipping...
# tumannyy,ru
# Processing Record 18 of Set 7 | tumannyy,ru
# City not found. Skipping...
# zaysan,kz
# Processing Record 19 of Set 7 | zaysan,kz
# chornobay,ua
# Processing Record 20 of Set 7 | chornobay,ua
# butajira,et
# Processing Record 21 of Set 7 | butajira,et
# ewa beach,us
# Processing Record 22 of Set 7 | ewa beach,us
# tessalit,ml
# Processing Record 23 of Set 7 | tessalit,ml
# daxian,cn
# Processing Record 24 of Set 7 | daxian,cn
# City not found. Skipping...
# port hardy,ca
# Processing Record 25 of Set 7 | port hardy,ca
# pangnirtung,ca
# Processing Record 26 of Set 7 | pangnirtung,ca
# egvekinot,ru
# Processing Record 27 of Set 7 | egvekinot,ru
# yazoo city,us
# Processing Record 28 of Set 7 | yazoo city,us
# puerto leguizamo,co
# Processing Record 29 of Set 7 | puerto leguizamo,co
# arzgir,ru
# Processing Record 30 of Set 7 | arzgir,ru
# palabuhanratu,id
# Processing Record 31 of Set 7 | palabuhanratu,id
# City not found. Skipping...
# vila,vu
# Processing Record 32 of Set 7 | vila,vu
# City not found. Skipping...
# umm kaddadah,sd
# Processing Record 33 of Set 7 | umm kaddadah,sd
# el alto,pe
# Processing Record 34 of Set 7 | el alto,pe
# puerto escondido,mx
# Processing Record 35 of Set 7 | puerto escondido,mx
# wajid,so
# Processing Record 36 of Set 7 | wajid,so
# diffa,ne
# Processing Record 37 of Set 7 | diffa,ne
# sola,vu
# Processing Record 38 of Set 7 | sola,vu
# constitucion,mx
# Processing Record 39 of Set 7 | constitucion,mx
# vrangel,ru
# Processing Record 40 of Set 7 | vrangel,ru
# portales,us
# Processing Record 41 of Set 7 | portales,us
# san patricio,mx
# Processing Record 42 of Set 7 | san patricio,mx
# hohhot,cn
# Processing Record 43 of Set 7 | hohhot,cn
# sao filipe,cv
# Processing Record 44 of Set 7 | sao filipe,cv
# cherskiy,ru
# Processing Record 45 of Set 7 | cherskiy,ru
# mangrol,in
# Processing Record 46 of Set 7 | mangrol,in
# leningradskiy,ru
# Processing Record 47 of Set 7 | leningradskiy,ru
# saint-philippe,re
# Processing Record 48 of Set 7 | saint-philippe,re
# shaunavon,ca
# Processing Record 49 of Set 7 | shaunavon,ca
# caluquembe,ao
# Processing Record 50 of Set 7 | caluquembe,ao
# dauphin,ca
# Processing Record 1 of Set 8 | dauphin,ca
# trzebnica,pl
# Processing Record 2 of Set 8 | trzebnica,pl
# bollnas,se
# Processing Record 3 of Set 8 | bollnas,se
# namtsy,ru
# Processing Record 4 of Set 8 | namtsy,ru
# neiafu,to
# Processing Record 5 of Set 8 | neiafu,to
# vardo,no
# Processing Record 6 of Set 8 | vardo,no
# narsaq,gl
# Processing Record 7 of Set 8 | narsaq,gl
# lakhdenpokhya,ru
# Processing Record 8 of Set 8 | lakhdenpokhya,ru
# broken hill,au
# Processing Record 9 of Set 8 | broken hill,au
# tondol,ph
# Processing Record 10 of Set 8 | tondol,ph
# lawton,us
# Processing Record 11 of Set 8 | lawton,us
# akyab,mm
# Processing Record 12 of Set 8 | akyab,mm
# wasilla,us
# Processing Record 13 of Set 8 | wasilla,us
# la asuncion,ve
# Processing Record 14 of Set 8 | la asuncion,ve
# teguise,es
# Processing Record 15 of Set 8 | teguise,es
# samalaeulu,ws
# Processing Record 16 of Set 8 | samalaeulu,ws
# City not found. Skipping...
# oum hadjer,td
# Processing Record 17 of Set 8 | oum hadjer,td
# tilichiki,ru
# Processing Record 18 of Set 8 | tilichiki,ru
# beloha,mg
# Processing Record 19 of Set 8 | beloha,mg
# nguiu,au
# Processing Record 20 of Set 8 | nguiu,au
# City not found. Skipping...
# aflu,dz
# Processing Record 21 of Set 8 | aflu,dz
# City not found. Skipping...
# anshun,cn
# Processing Record 22 of Set 8 | anshun,cn
# codrington,ag
# Processing Record 23 of Set 8 | codrington,ag
# City not found. Skipping...
# izhma,ru
# Processing Record 24 of Set 8 | izhma,ru
# mount gambier,au
# Processing Record 25 of Set 8 | mount gambier,au
# nuuk,gl
# Processing Record 26 of Set 8 | nuuk,gl
# joutseno,fi
# Processing Record 27 of Set 8 | joutseno,fi
# shelburne,ca
# Processing Record 28 of Set 8 | shelburne,ca
# tual,id
# Processing Record 29 of Set 8 | tual,id
# troitskoye,ru
# Processing Record 30 of Set 8 | troitskoye,ru
# bambous virieux,mu
# Processing Record 31 of Set 8 | bambous virieux,mu
# sept-iles,ca
# Processing Record 32 of Set 8 | sept-iles,ca
# cairns,au
# Processing Record 33 of Set 8 | cairns,au
# boguchany,ru
# Processing Record 34 of Set 8 | boguchany,ru
# montlucon,fr
# Processing Record 35 of Set 8 | montlucon,fr
# haines junction,ca
# Processing Record 36 of Set 8 | haines junction,ca
# lamovita,ba
# Processing Record 37 of Set 8 | lamovita,ba
# poum,nc
# Processing Record 38 of Set 8 | poum,nc
# esperance,au
# Processing Record 39 of Set 8 | esperance,au
# clyde river,ca
# Processing Record 40 of Set 8 | clyde river,ca
# sur,om
# Processing Record 41 of Set 8 | sur,om
# limon,hn
# Processing Record 42 of Set 8 | limon,hn
# vanavara,ru
# Processing Record 43 of Set 8 | vanavara,ru
# hualmay,pe
# Processing Record 44 of Set 8 | hualmay,pe
# harper,lr
# Processing Record 45 of Set 8 | harper,lr
# ondjiva,ao
# Processing Record 46 of Set 8 | ondjiva,ao
# vuktyl,ru
# Processing Record 47 of Set 8 | vuktyl,ru
# karangampel,id
# Processing Record 48 of Set 8 | karangampel,id
# kavieng,pg
# Processing Record 49 of Set 8 | kavieng,pg
# mandurah,au
# Processing Record 50 of Set 8 | mandurah,au
# navolato,mx
# Processing Record 1 of Set 9 | navolato,mx
# pushkinskiye gory,ru
# Processing Record 2 of Set 9 | pushkinskiye gory,ru
# banda aceh,id
# Processing Record 3 of Set 9 | banda aceh,id
# flin flon,ca
# Processing Record 4 of Set 9 | flin flon,ca
# ratnagiri,in
# Processing Record 5 of Set 9 | ratnagiri,in
# diapaga,bf
# Processing Record 6 of Set 9 | diapaga,bf
# kruisfontein,za
# Processing Record 7 of Set 9 | kruisfontein,za
# shubarshi,kz
# Processing Record 8 of Set 9 | shubarshi,kz
# nemuro,jp
# Processing Record 9 of Set 9 | nemuro,jp
# luanda,ao
# Processing Record 10 of Set 9 | luanda,ao
# horsham,au
# Processing Record 11 of Set 9 | horsham,au
# te anau,nz
# Processing Record 12 of Set 9 | te anau,nz
# kenai,us
# Processing Record 13 of Set 9 | kenai,us
# tahoua,ne
# Processing Record 14 of Set 9 | tahoua,ne
# tondano,id
# Processing Record 15 of Set 9 | tondano,id
# basoko,cd
# Processing Record 16 of Set 9 | basoko,cd
# hirado,jp
# Processing Record 17 of Set 9 | hirado,jp
# fortuna,us
# Processing Record 18 of Set 9 | fortuna,us
# port-gentil,ga
# Processing Record 19 of Set 9 | port-gentil,ga
# victoria point,au
# Processing Record 20 of Set 9 | victoria point,au
# salinopolis,br
# Processing Record 21 of Set 9 | salinopolis,br
# makakilo city,us
# Processing Record 22 of Set 9 | makakilo city,us
# buriti bravo,br
# Processing Record 23 of Set 9 | buriti bravo,br
# burley,us
# Processing Record 24 of Set 9 | burley,us
# togur,ru
# Processing Record 25 of Set 9 | togur,ru
# key west,us
# Processing Record 26 of Set 9 | key west,us
# kokkola,fi
# Processing Record 27 of Set 9 | kokkola,fi
# kataysk,ru
# Processing Record 28 of Set 9 | kataysk,ru
# ludvika,se
# Processing Record 29 of Set 9 | ludvika,se
# nigde,tr
# Processing Record 30 of Set 9 | nigde,tr
# abu samrah,qa
# Processing Record 31 of Set 9 | abu samrah,qa
# City not found. Skipping...
# liuhe,cn
# Processing Record 32 of Set 9 | liuhe,cn
# atar,mr
# Processing Record 33 of Set 9 | atar,mr
# pisco,pe
# Processing Record 34 of Set 9 | pisco,pe
# zolotinka,ru
# Processing Record 35 of Set 9 | zolotinka,ru
# City not found. Skipping...
# kaeo,nz
# Processing Record 36 of Set 9 | kaeo,nz
# alta,no
# Processing Record 37 of Set 9 | alta,no
# kamenskoye,ru
# Processing Record 38 of Set 9 | kamenskoye,ru
# City not found. Skipping...
# columbus,us
# Processing Record 39 of Set 9 | columbus,us
# thompson,ca
# Processing Record 40 of Set 9 | thompson,ca
# san quintin,mx
# Processing Record 41 of Set 9 | san quintin,mx
# bang saphan,th
# Processing Record 42 of Set 9 | bang saphan,th
# hamilton,bm
# Processing Record 43 of Set 9 | hamilton,bm
# waitati,nz
# Processing Record 44 of Set 9 | waitati,nz
# sid,rs
# Processing Record 45 of Set 9 | sid,rs
# oxbow,ca
# Processing Record 46 of Set 9 | oxbow,ca
# yabrud,sy
# Processing Record 47 of Set 9 | yabrud,sy
# ust-ishim,ru
# Processing Record 48 of Set 9 | ust-ishim,ru
# fort nelson,ca
# Processing Record 49 of Set 9 | fort nelson,ca
# rio frio,mx
# Processing Record 50 of Set 9 | rio frio,mx
# bahia honda,cu
# Processing Record 1 of Set 10 | bahia honda,cu
# upata,ve
# Processing Record 2 of Set 10 | upata,ve
# bucerias,mx
# Processing Record 3 of Set 10 | bucerias,mx
# cayenne,gf
# Processing Record 4 of Set 10 | cayenne,gf
# sulangan,ph
# Processing Record 5 of Set 10 | sulangan,ph
# kathu,th
# Processing Record 6 of Set 10 | kathu,th
# sturgeon falls,ca
# Processing Record 7 of Set 10 | sturgeon falls,ca
# touros,br
# Processing Record 8 of Set 10 | touros,br
# acapulco,mx
# Processing Record 9 of Set 10 | acapulco,mx
# tamworth,au
# Processing Record 10 of Set 10 | tamworth,au
# kudal,in
# Processing Record 11 of Set 10 | kudal,in
# pimenta bueno,br
# Processing Record 12 of Set 10 | pimenta bueno,br
# daura,ng
# Processing Record 13 of Set 10 | daura,ng
# chabahar,ir
# Processing Record 14 of Set 10 | chabahar,ir
# anloga,gh
# Processing Record 15 of Set 10 | anloga,gh
# amderma,ru
# Processing Record 16 of Set 10 | amderma,ru
# City not found. Skipping...
# dakar,sn
# Processing Record 17 of Set 10 | dakar,sn
# safwah,sa
# Processing Record 18 of Set 10 | safwah,sa
# City not found. Skipping...
# prieska,za
# Processing Record 19 of Set 10 | prieska,za
# tsiroanomandidy,mg
# Processing Record 20 of Set 10 | tsiroanomandidy,mg
# chekmagush,ru
# Processing Record 21 of Set 10 | chekmagush,ru
# minab,ir
# Processing Record 22 of Set 10 | minab,ir
# kandrian,pg
# Processing Record 23 of Set 10 | kandrian,pg
# marcona,pe
# Processing Record 24 of Set 10 | marcona,pe
# City not found. Skipping...
# bam,ir
# Processing Record 25 of Set 10 | bam,ir
# charters towers,au
# Processing Record 26 of Set 10 | charters towers,au
# scalloway,gb
# Processing Record 27 of Set 10 | scalloway,gb
# City not found. Skipping...
# labuhan,id
# Processing Record 28 of Set 10 | labuhan,id
# saint george,bm
# Processing Record 29 of Set 10 | saint george,bm
# mapiri,bo
# Processing Record 30 of Set 10 | mapiri,bo
# ames,us
# Processing Record 31 of Set 10 | ames,us
# berlevag,no
# Processing Record 32 of Set 10 | berlevag,no
# mehamn,no
# Processing Record 33 of Set 10 | mehamn,no
# calama,cl
# Processing Record 34 of Set 10 | calama,cl
# wala,pa
# Processing Record 35 of Set 10 | wala,pa
# City not found. Skipping...
# hambantota,lk
# Processing Record 36 of Set 10 | hambantota,lk
# eyl,so
# Processing Record 37 of Set 10 | eyl,so
# portland,au
# Processing Record 38 of Set 10 | portland,au
# araouane,ml
# Processing Record 39 of Set 10 | araouane,ml
# limoeiro do norte,br
# Processing Record 40 of Set 10 | limoeiro do norte,br
# sotouboua,tg
# Processing Record 41 of Set 10 | sotouboua,tg
# qandala,so
# Processing Record 42 of Set 10 | qandala,so
# moyale,et
# Processing Record 43 of Set 10 | moyale,et
# gravdal,no
# Processing Record 44 of Set 10 | gravdal,no
# tsaratanana,mg
# Processing Record 45 of Set 10 | tsaratanana,mg
# mehran,ir
# Processing Record 46 of Set 10 | mehran,ir
# boyolangu,id
# Processing Record 47 of Set 10 | boyolangu,id
# shimoda,jp
# Processing Record 48 of Set 10 | shimoda,jp
# noyabrsk,ru
# Processing Record 49 of Set 10 | noyabrsk,ru
# jieshou,cn
# Processing Record 50 of Set 10 | jieshou,cn
# vaitupu,wf
# Processing Record 1 of Set 11 | vaitupu,wf
# City not found. Skipping...
# hasilpur,pk
# Processing Record 2 of Set 11 | hasilpur,pk
# kashi,cn
# Processing Record 3 of Set 11 | kashi,cn
# ballarat,au
# Processing Record 4 of Set 11 | ballarat,au
# gulf gate estates,us
# Processing Record 5 of Set 11 | gulf gate estates,us
# baker city,us
# Processing Record 6 of Set 11 | baker city,us
# dongsheng,cn
# Processing Record 7 of Set 11 | dongsheng,cn
# mollendo,pe
# Processing Record 8 of Set 11 | mollendo,pe
# jiaozuo,cn
# Processing Record 9 of Set 11 | jiaozuo,cn
# xichang,cn
# Processing Record 10 of Set 11 | xichang,cn
# melsungen,de
# Processing Record 11 of Set 11 | melsungen,de
# coihaique,cl
# Processing Record 12 of Set 11 | coihaique,cl
# vreed en hoop,gy
# Processing Record 13 of Set 11 | vreed en hoop,gy
# City not found. Skipping...
# bukachacha,ru
# Processing Record 14 of Set 11 | bukachacha,ru
# tonantins,br
# Processing Record 15 of Set 11 | tonantins,br
# namibe,ao
# Processing Record 16 of Set 11 | namibe,ao
# valparaiso,co
# Processing Record 17 of Set 11 | valparaiso,co
# iguape,br
# Processing Record 18 of Set 11 | iguape,br
# ayagoz,kz
# Processing Record 19 of Set 11 | ayagoz,kz
# moerai,pf
# Processing Record 20 of Set 11 | moerai,pf
# masuda,jp
# Processing Record 21 of Set 11 | masuda,jp
# roma,au
# Processing Record 22 of Set 11 | roma,au
# inongo,cd
# Processing Record 23 of Set 11 | inongo,cd
# paamiut,gl
# Processing Record 24 of Set 11 | paamiut,gl
# cockburn town,tc
# Processing Record 25 of Set 11 | cockburn town,tc
# podyuga,ru
# Processing Record 26 of Set 11 | podyuga,ru
# waiuku,nz
# Processing Record 27 of Set 11 | waiuku,nz
# padang,id
# Processing Record 28 of Set 11 | padang,id
# monte patria,cl
# Processing Record 29 of Set 11 | monte patria,cl
# traralgon,au
# Processing Record 30 of Set 11 | traralgon,au
# hervey bay,au
# Processing Record 31 of Set 11 | hervey bay,au
# kahului,us
# Processing Record 32 of Set 11 | kahului,us
# tongchuan,cn
# Processing Record 33 of Set 11 | tongchuan,cn
# coahuayana,mx
# Processing Record 34 of Set 11 | coahuayana,mx
# salta,ar
# Processing Record 35 of Set 11 | salta,ar
# igarape-miri,br
# Processing Record 36 of Set 11 | igarape-miri,br
# City not found. Skipping...
# altamira,br
# Processing Record 37 of Set 11 | altamira,br
# rodrigues alves,br
# Processing Record 38 of Set 11 | rodrigues alves,br
# bolungarvik,is
# Processing Record 39 of Set 11 | bolungarvik,is
# City not found. Skipping...
# taybad,ir
# Processing Record 40 of Set 11 | taybad,ir
# bakchar,ru
# Processing Record 41 of Set 11 | bakchar,ru
# prince rupert,ca
# Processing Record 42 of Set 11 | prince rupert,ca
# talara,pe
# Processing Record 43 of Set 11 | talara,pe
# yumen,cn
# Processing Record 44 of Set 11 | yumen,cn
# sungaipenuh,id
# Processing Record 45 of Set 11 | sungaipenuh,id
# los llanos de aridane,es
# Processing Record 46 of Set 11 | los llanos de aridane,es
# north bend,us
# Processing Record 47 of Set 11 | north bend,us
# port lincoln,au
# Processing Record 48 of Set 11 | port lincoln,au
# husavik,is
# Processing Record 49 of Set 11 | husavik,is
# tha bo,th
# Processing Record 50 of Set 11 | tha bo,th
# freeport,bs
# Processing Record 1 of Set 12 | freeport,bs
# olafsvik,is
# Processing Record 2 of Set 12 | olafsvik,is
# cordele,us
# Processing Record 3 of Set 12 | cordele,us
# praia,cv
# Processing Record 4 of Set 12 | praia,cv
# gazli,uz
# Processing Record 5 of Set 12 | gazli,uz
# wahran,dz
# Processing Record 6 of Set 12 | wahran,dz
# City not found. Skipping...
# kuala terengganu,my
# Processing Record 7 of Set 12 | kuala terengganu,my
# enshi,cn
# Processing Record 8 of Set 12 | enshi,cn
# itacarambi,br
# Processing Record 9 of Set 12 | itacarambi,br
# skjervoy,no
# Processing Record 10 of Set 12 | skjervoy,no
# baoding,cn
# Processing Record 11 of Set 12 | baoding,cn
# sumenep,id
# Processing Record 12 of Set 12 | sumenep,id
# makueni,ke
# Processing Record 13 of Set 12 | makueni,ke
# astana,kz
# Processing Record 14 of Set 12 | astana,kz
# guia de isora,es
# Processing Record 15 of Set 12 | guia de isora,es
# angoche,mz
# Processing Record 16 of Set 12 | angoche,mz
# atambua,id
# Processing Record 17 of Set 12 | atambua,id
# auray,fr
# Processing Record 18 of Set 12 | auray,fr
# ust-tsilma,ru
# Processing Record 19 of Set 12 | ust-tsilma,ru
# diego de almagro,cl
# Processing Record 20 of Set 12 | diego de almagro,cl
# lahaina,us
# Processing Record 21 of Set 12 | lahaina,us
# taltal,cl
# Processing Record 22 of Set 12 | taltal,cl
# tashtyp,ru
# Processing Record 23 of Set 12 | tashtyp,ru
# kloulklubed,pw
# Processing Record 24 of Set 12 | kloulklubed,pw
# pambisan,ph
# Processing Record 25 of Set 12 | pambisan,ph
# hovd,mn
# Processing Record 26 of Set 12 | hovd,mn
# ekibastuz,kz
# Processing Record 27 of Set 12 | ekibastuz,kz
# vagay,ru
# Processing Record 28 of Set 12 | vagay,ru
# sangar,ru
# Processing Record 29 of Set 12 | sangar,ru
# toftir,fo
# Processing Record 30 of Set 12 | toftir,fo
# City not found. Skipping...
# cabimas,ve
# Processing Record 31 of Set 12 | cabimas,ve
# mocuba,mz
# Processing Record 32 of Set 12 | mocuba,mz
# vanderbijlpark,za
# Processing Record 33 of Set 12 | vanderbijlpark,za
# kedrovyy,ru
# Processing Record 34 of Set 12 | kedrovyy,ru
# buckeye,us
# Processing Record 35 of Set 12 | buckeye,us
# christchurch,nz
# Processing Record 36 of Set 12 | christchurch,nz
# rorvik,no
# Processing Record 37 of Set 12 | rorvik,no
# halkirk,gb
# Processing Record 38 of Set 12 | halkirk,gb
# santarem,br
# Processing Record 39 of Set 12 | santarem,br
# uk,ru
# Processing Record 40 of Set 12 | uk,ru
# porbandar,in
# Processing Record 41 of Set 12 | porbandar,in
# santa isabel do rio negro,br
# Processing Record 42 of Set 12 | santa isabel do rio negro,br
# houma,us
# Processing Record 43 of Set 12 | houma,us
# westport,nz
# Processing Record 44 of Set 12 | westport,nz
# cap-aux-meules,ca
# Processing Record 45 of Set 12 | cap-aux-meules,ca
# baykit,ru
# Processing Record 46 of Set 12 | baykit,ru
# mananjary,mg
# Processing Record 47 of Set 12 | mananjary,mg
# robertson,za
# Processing Record 48 of Set 12 | robertson,za
# homer,us
# Processing Record 49 of Set 12 | homer,us
# panguna,pg
# Processing Record 50 of Set 12 | panguna,pg
# dekoa,cf
# Processing Record 1 of Set 13 | dekoa,cf
# City not found. Skipping...
# buin,pg
# Processing Record 2 of Set 13 | buin,pg
# City not found. Skipping...
# macedo de cavaleiros,pt
# Processing Record 3 of Set 13 | macedo de cavaleiros,pt
# bilma,ne
# Processing Record 4 of Set 13 | bilma,ne
# ambilobe,mg
# Processing Record 5 of Set 13 | ambilobe,mg
# miraflores,co
# Processing Record 6 of Set 13 | miraflores,co
# half moon bay,us
# Processing Record 7 of Set 13 | half moon bay,us
# lakes entrance,au
# Processing Record 8 of Set 13 | lakes entrance,au
# teguldet,ru
# Processing Record 9 of Set 13 | teguldet,ru
# huilong,cn
# Processing Record 10 of Set 13 | huilong,cn
# lagdo,cm
# Processing Record 11 of Set 13 | lagdo,cm
# wadi musa,jo
# Processing Record 12 of Set 13 | wadi musa,jo
# pizarro,co
# Processing Record 13 of Set 13 | pizarro,co
# srednekolymsk,ru
# Processing Record 14 of Set 13 | srednekolymsk,ru
# bouar,cf
# Processing Record 15 of Set 13 | bouar,cf
# werda,bw
# Processing Record 16 of Set 13 | werda,bw
# bafata,gw
# Processing Record 17 of Set 13 | bafata,gw
# moose factory,ca
# Processing Record 18 of Set 13 | moose factory,ca
# le port,re
# Processing Record 19 of Set 13 | le port,re
# vanimo,pg
# Processing Record 20 of Set 13 | vanimo,pg
# ketchikan,us
# Processing Record 21 of Set 13 | ketchikan,us
# aksarka,ru
# Processing Record 22 of Set 13 | aksarka,ru
# lillehammer,no
# Processing Record 23 of Set 13 | lillehammer,no
# plettenberg bay,za
# Processing Record 24 of Set 13 | plettenberg bay,za
# bauchi,ng
# Processing Record 25 of Set 13 | bauchi,ng
# kontagora,ng
# Processing Record 26 of Set 13 | kontagora,ng
# tiznit,ma
# Processing Record 27 of Set 13 | tiznit,ma
# verkhnevilyuysk,ru
# Processing Record 28 of Set 13 | verkhnevilyuysk,ru
# galesong,id
# Processing Record 29 of Set 13 | galesong,id
# felanitx,es
# Processing Record 30 of Set 13 | felanitx,es
# gulu,ug
# Processing Record 31 of Set 13 | gulu,ug
# natal,br
# Processing Record 32 of Set 13 | natal,br
# kavaratti,in
# Processing Record 33 of Set 13 | kavaratti,in
# puerto baquerizo moreno,ec
# Processing Record 34 of Set 13 | puerto baquerizo moreno,ec
# aklavik,ca
# Processing Record 35 of Set 13 | aklavik,ca
# bhatkal,in
# Processing Record 36 of Set 13 | bhatkal,in
# cockburn town,bs
# Processing Record 37 of Set 13 | cockburn town,bs
# itarema,br
# Processing Record 38 of Set 13 | itarema,br
# sorland,no
# Processing Record 39 of Set 13 | sorland,no
# san juan,ar
# Processing Record 40 of Set 13 | san juan,ar
# mitu,co
# Processing Record 41 of Set 13 | mitu,co
# kachug,ru
# Processing Record 42 of Set 13 | kachug,ru
# pitimbu,br
# Processing Record 43 of Set 13 | pitimbu,br
# sao geraldo do araguaia,br
# Processing Record 44 of Set 13 | sao geraldo do araguaia,br
# trairi,br
# Processing Record 45 of Set 13 | trairi,br
# west plains,us
# Processing Record 46 of Set 13 | west plains,us
# lizzano,it
# Processing Record 47 of Set 13 | lizzano,it
# weiser,us
# Processing Record 48 of Set 13 | weiser,us
# netarhat,in
# Processing Record 49 of Set 13 | netarhat,in
# mumford,gh
# Processing Record 50 of Set 13 | mumford,gh
# katangli,ru
# Processing Record 1 of Set 14 | katangli,ru
# aquiraz,br
# Processing Record 2 of Set 14 | aquiraz,br
# wangqing,cn
# Processing Record 3 of Set 14 | wangqing,cn
# maniitsoq,gl
# Processing Record 4 of Set 14 | maniitsoq,gl
# camana,pe
# Processing Record 5 of Set 14 | camana,pe
# disna,by
# Processing Record 6 of Set 14 | disna,by
# carlsbad,us
# Processing Record 7 of Set 14 | carlsbad,us
# mamou,gn
# Processing Record 8 of Set 14 | mamou,gn
# kautokeino,no
# Processing Record 9 of Set 14 | kautokeino,no
# flinders,au
# Processing Record 10 of Set 14 | flinders,au
# linxia,cn
# Processing Record 11 of Set 14 | linxia,cn
# rusape,zw
# Processing Record 12 of Set 14 | rusape,zw
# stykkisholmur,is
# Processing Record 13 of Set 14 | stykkisholmur,is
# saint-denis,re
# Processing Record 14 of Set 14 | saint-denis,re
# gat,ly
# Processing Record 15 of Set 14 | gat,ly
# City not found. Skipping...
# bolobo,cd
# Processing Record 16 of Set 14 | bolobo,cd
# sorong,id
# Processing Record 17 of Set 14 | sorong,id
# toliary,mg
# Processing Record 18 of Set 14 | toliary,mg
# City not found. Skipping...
# nanchang,cn
# Processing Record 19 of Set 14 | nanchang,cn
# eskasem,af
# Processing Record 20 of Set 14 | eskasem,af
# City not found. Skipping...
# selenginsk,ru
# Processing Record 21 of Set 14 | selenginsk,ru
# balabac,ph
# Processing Record 22 of Set 14 | balabac,ph
# tura,ru
# Processing Record 23 of Set 14 | tura,ru
# falmouth,jm
# Processing Record 24 of Set 14 | falmouth,jm
# inuvik,ca
# Processing Record 25 of Set 14 | inuvik,ca
# komsomolskiy,ru
# Processing Record 26 of Set 14 | komsomolskiy,ru
# novo aripuana,br
# Processing Record 27 of Set 14 | novo aripuana,br
# palmas bellas,pa
# Processing Record 28 of Set 14 | palmas bellas,pa
# miramar,mx
# Processing Record 29 of Set 14 | miramar,mx
# ranfurly,nz
# Processing Record 30 of Set 14 | ranfurly,nz
# bandar-e lengeh,ir
# Processing Record 31 of Set 14 | bandar-e lengeh,ir
# namatanai,pg
# Processing Record 32 of Set 14 | namatanai,pg
# san pedro,bz
# Processing Record 33 of Set 14 | san pedro,bz
# naze,jp
# Processing Record 34 of Set 14 | naze,jp
# along,in
# Processing Record 35 of Set 14 | along,in
# port-cartier,ca
# Processing Record 36 of Set 14 | port-cartier,ca
# pucallpa,pe
# Processing Record 37 of Set 14 | pucallpa,pe
# khuzhir,ru
# Processing Record 38 of Set 14 | khuzhir,ru
# yar,ru
# Processing Record 39 of Set 14 | yar,ru
# zhuhai,cn
# Processing Record 40 of Set 14 | zhuhai,cn
# itaituba,br
# Processing Record 41 of Set 14 | itaituba,br
# barcelos,br
# Processing Record 42 of Set 14 | barcelos,br
# carman,ca
# Processing Record 43 of Set 14 | carman,ca
# balasinor,in
# Processing Record 44 of Set 14 | balasinor,in
# City not found. Skipping...
# garoua boulai,cm
# Processing Record 45 of Set 14 | garoua boulai,cm
# berdigestyakh,ru
# Processing Record 46 of Set 14 | berdigestyakh,ru
# bandundu,cd
# Processing Record 47 of Set 14 | bandundu,cd
# santiago del estero,ar
# Processing Record 48 of Set 14 | santiago del estero,ar
# kamloops,ca
# Processing Record 49 of Set 14 | kamloops,ca
# rawannawi,ki
# Processing Record 50 of Set 14 | rawannawi,ki
# City not found. Skipping...
# enterprise,us
# Processing Record 1 of Set 15 | enterprise,us
# kudahuvadhoo,mv
# Processing Record 2 of Set 15 | kudahuvadhoo,mv
# umm lajj,sa
# Processing Record 3 of Set 15 | umm lajj,sa
# wamba,cd
# Processing Record 4 of Set 15 | wamba,cd
# koumac,nc
# Processing Record 5 of Set 15 | koumac,nc
# nishihara,jp
# Processing Record 6 of Set 15 | nishihara,jp
# suntar,ru
# Processing Record 7 of Set 15 | suntar,ru
# storforshei,no
# Processing Record 8 of Set 15 | storforshei,no
# cotonou,bj
# Processing Record 9 of Set 15 | cotonou,bj
# vidim,ru
# Processing Record 10 of Set 15 | vidim,ru
# northam,au
# Processing Record 11 of Set 15 | northam,au
# taksimo,ru
# Processing Record 12 of Set 15 | taksimo,ru
# santa rosa,co
# Processing Record 13 of Set 15 | santa rosa,co
# tokmak,kg
# Processing Record 14 of Set 15 | tokmak,kg
# City not found. Skipping...
# port augusta,au
# Processing Record 15 of Set 15 | port augusta,au
# bhinmal,in
# Processing Record 16 of Set 15 | bhinmal,in
# sibu,my
# Processing Record 17 of Set 15 | sibu,my
# kulhudhuffushi,mv
# Processing Record 18 of Set 15 | kulhudhuffushi,mv
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#                City      Lat       Lng          Weather  Max Temp  Humidity  \
# 0       San Jose,Bo -17.9389  -63.3516  overcast clouds     75.00        50
# 1      El Carmen,Co   8.5106  -73.4478  overcast clouds     65.14        97
# 2      Sarangani,Ph   5.4033  125.4636    broken clouds     82.35        70
# 3   Punta Arenas,Cl -53.1500  -70.9167        clear sky     35.71        87
# 4  Mar Del Plata,Ar -38.0023  -57.5575  overcast clouds     55.42       100
#
#    Cloudiness  Wind Speed Country                 Date
# 0          97       10.85      BO  2021-09-20 07:49:31
# 1         100        3.58      CO  2021-09-20 07:49:33
# 2          81        3.38      PH  2021-09-20 07:49:34
# 3           0        6.91      CL  2021-09-20 07:49:35
# 4          90        4.61      AR  2021-09-20 07:49:10

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
